# %%
import random
import pyautogui as pg
import webbrowser as web
import time
import sys

try:
    message = """message"""


    # first = Tru
    with open('numbers.txt') as file:
        for line in file.readlines():
            time.sleep(2)
            web.open("https://web.whatsapp.com/send?phone="+line+"&text="+message)
    #         if first:
    #             time.sleep(6)
    #             first=False
            time.sleep(20)
            x,y = pg.size()
            x,y=int(str(x)),int(str(y))

            pg.click(x/1.5,y/1.5)

            time.sleep(random.randint(25,45))
#             time.sleep(5)
            pg.press('enter')
            time.sleep(8)
            pg.hotkey('ctrl', 'w')
except KeyboardInterrupt:
    sys.exit()
